# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as BS
import pandas as pd
import numpy as np
import time
import requests
import re

# %%
link_group = []
city_list = []
pages = []
company_list = []
job_list = []
salary_list = []
state_list =[]
search_links = ['https://www.indeed.com/jobs?q=%22data+scientist%22+%2420%2C000%2B&l=', 'https://www.indeed.com/jobs?q=%22quantitative+research%22+%2420%2C000%2B&l=', 'https://www.indeed.com/jobs?q=%22data+engineer%22+%2420%2C000%2B&l=',
                'https://www.indeed.com/jobs?q=%22business+intelligence%22+%2420%2C000%2B&l=', 'https://www.indeed.com/jobs?q=%22business+analyst%22+%2420%2C000%2B&l=','https://www.indeed.com/jobs?q=%22data+consultant%22+%2450%2C000&l=']

#find links of the next 5 search pages
for link in search_links:
    website = requests.get(link)
    website_object = BS(website.text, 'html.parser')
    for div in website_object.find_all('div', attrs = {'class':'pagination'}):
        for a in div.find_all('a', attrs = {'onmousedown': 'addPPUrlParam && addPPUrlParam(this);'}):
            pages.append(a['href'])

new_pages = ['https://www.indeed.com{0}'.format(i) for i in pages]

#find individual links in each search page
for link in new_pages:
    search_page = requests.get(link)
    time.sleep(0.1)
    search_page_object = BS(search_page.text, 'html.parser')
    for posting in search_page_object.find_all('div', attrs={'class':'title'}):
        for a in posting.find_all('a', attrs = {'data-tn-element': 'jobTitle'}):
            link_group.append(a['href'])  #get individual posting's link to full page 
    for posting in search_page_object.find_all('div', attrs = {'class': 'recJobLoc'}):
        temp1=posting['data-rc-loc'].split(',')
        city_list.append(temp1[0])
        state_list.append(temp1[len(temp1)-1]) #get location
    for posting in search_page_object.find_all('div', attrs = {'class': 'row'}):
        for a in posting.find_all('a', attrs = {'data-tn-element': 'jobTitle'}):
            job_list.append(a['title']) #get job title
        for span in posting.find_all('span', attrs = {'class':'company'}):
            company_list.append(span.get_text().replace('\n', '')) #get company

   
new_links = ['https://www.indeed.com{0}'.format(i) for i in link_group]

# %%
def search_function(page_object): 
    keywords=['bash','python','java','c++','ruby','perl','javascript','scala','matlab'
                          'php','excel','data mining','spss','big data',
                          'd3.js','sas','d3','sps','mahout','cobol'
                          'spotfire','scikit.learn','splunk','h2o','hadoop','mapreduce','spark','pig',
                          'hive','shark','sql','nosql','hbase','cassandra','mongodb','mysql','mssql',
                          'postgresql','bigquery','aws','machine learning','deep learning','visualization',
                          'artificial intelligence','azure','tableau', 'alteryx', 'postgres',
                          'sqoop','yarn','c#','etl','unix','linux','shell']
    
    education_list = ['master','bachelor','be','ms','phd','doctorate','ba','bs']
    experience_data_list = ['1 year','1+ years','1 or more years','2 years','2+ years','2 or more years','3 years',
                     '3+ years','3 or more years','4 years','4+ years','4 or more years','5 years','5+ years','5 or more years']

    experience_temp = []
    temp_exp = []
    degree = ''
    job_description = ''
    salary = ''
    
    #find job description
    for div in page_object.find_all(name = 'div', attrs = {'id':'jobDescriptionText'}):
        job_description = div.get_text().replace('\n', ' ').lower() 
    
    #find experience requirement
    for i in experience_data_list:
         if(job_description.find(i, 0) > 0):
                experience_temp.append(i)
                
    for m in experience_temp:
        if len(m.split(" ")[0].split("+"))==2:
            temp_exp.append(int(m.split(" ")[0].split("+")[0]))
        else:
            temp_exp.append(int(m.split(" ")[0]))    
    max_exp=0
    if len(temp_exp)==0:
        max_exp=0
    else:
        max_exp=max(temp_exp) 
    
    #find skills
    keyword=''    
    for j in keywords:
         if(job_description.find(j, 0) > 0):
                if keyword=='':
                    keyword=j
                else:
                    keyword=keyword+','+j
    
    #find salary
    for posting in page_object.find_all('div', attrs = {'class': 'jobsearch-JobMetadataHeader-item'}):
        for span in posting.find_all('span', attrs = {'class':'icl-u-xs-mr--xs'}):
            salary = span.get_text().replace('\n', '')
    avg_salary=AvgerageSalary(salary)
            
    #find education requirement
    for l in education_list:
        if(job_description.find(l,0) > 0):
            degree = l
                
    return {'job_description':job_description,'keyword':keyword,'Salary':avg_salary,'Education':degree,'Experience':max_exp}

# %%
def AvgerageSalary(Salary):
    import math
    AvgSalary=0
    MaxSalary=0
    MinSalary=0

    if Salary=='':
        AvgSalary=0
    else:
        if str(Salary).split(" ")[len(str(Salary).split(" "))-1]=='year':
                MinSalary=float((str(Salary).split(" ")[0].split("$")[1]).replace(",", ''))
                if len(str(Salary).split(" "))==3:
                    MaxSalary=float((str(Salary).split(" ")[0].split("$")[1]).replace(",", ''))
                else:
                    temp1=(str(Salary).split(" ")[2].split("$")[1]).replace(",", '')
                    MaxSalary=float(temp1)  
        elif str(Salary).split(" ")[len(str(Salary).split(" "))-1]=='month': 
                temp=(str(Salary).split(" ")[0].split("$")[1]).replace(",", '')
                MinSalary=float(temp)*12
                temp=(str(Salary).split(" ")[2].split("$")[1]).replace(",", '')
                MaxSalary=float(temp)*12
        elif str(Salary).split(" ")[len(str(Salary).split(" "))-1]=='hour':
                temp1=str(Salary).split(" ")[0].split("$")[1]
                MinSalary=float(temp1)*8*261
                if len(str(Salary).split(" "))==3:
                    MaxSalary=float(temp1)*8*261
                else:
                    temp1=(str(Salary).split(" ")[2].split("$")[1])
                    MaxSalary=float(temp1)*8*261
                    
    AvgSalary=(MinSalary+MaxSalary)/2
    return AvgSalary

# %%
i = 0
description_list = []
skill_list=[]
salary_list=[]
education_list=[]
experience_list=[]

while i < len(new_links):
    URL = new_links[i]
    page = requests.get(URL)
    page_object = BS(page.text, 'html.parser')
    result=search_function(page_object) 
    description_list.append(result['job_description'])
    skill_list.append(result['keyword'])
    salary_list.append(result['Salary'])
    education_list.append(result['Education'])
    experience_list.append(result['Experience'])
    i += 1

# %%
data = pd.DataFrame(list(zip(job_list, company_list, city_list,state_list, description_list, skill_list, salary_list, education_list,experience_list)), columns = ['Job Title', 'Company', 'City','State','Job Description','Skill Set','Salary', 'Education','Experience'])
#replacing 0-values in Education column as not mentioned
data.Education.replace('', 'Not Mentioned', inplace=True)
data
# Out:
#                                              Job Title  \
# 0                                Junior Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                 Staff Data Scientist
# 5             Data Scientist ( Data Bricks) ( ONLY W2)
# 6    Undergraduate Internship/Co-op Program - Data ...
# 7                                Junior Data Scientist
# 8                                       Data Scientist
# 9                    Data Scientist - New College Grad
# 10               Data Scientist - Predictive Analytics
# 11                                      Data Scientist
# 12                               Data Scientist Intern
# 13               Data Scientist - AI/ ML - Houston, TX
# 14                           Senior NLP Data Scientist
# 15                                      Data Scientist
# 16                                      Data Scientist
# 17                                      Data Scientist
# 18                                      Data Scientist
# 19                                      Data Scientist
# 20   Undergraduate Internship/Co-op Program - Data ...
# 21                               Junior Data Scientist
# 22                                      Data Scientist
# 23                                      Data Scientist
# 24                                Staff Data Scientist
# 25                  Data Scientist - Cost Intelligence
# 26                           Data Scientist - Matching
# 27                               Data Scientist Intern
# 28                                      Data Scientist
# 29   2019 University Graduate - Data Scientist - Ub...
# ..                                                 ...
# 505                          Associate Data Consultant
# 506                                Big Data Consultant
# 507                             Senior Data Consultant
# 508                             Senior Data Consultant
# 509         Principal Data Consultant - User Telemetry
# 510                           Sr. Fast Data Consultant
# 511                    Informatica Big Data Consultant
# 512         Principal Data Consultant - User Telemetry
# 513                                      Data Engineer
# 514  Senior Data Consultant - Data Science/SaaS (50...
# 515         Research and Instructional Data Consultant
# 516              Provider Data Consultant - Telecomute
# 517  Big Data Consultant / Architect - Fortune 100 ...
# 518         Accenture DayNine- Workday Data Consultant
# 519  Big Data Consultant / Architect - Fortune 100 ...
# 520              Provider Data Consultant - Telecomute
# 521                                 Big Data Architect
# 522                                      Data Engineer
# 523                          Marketing Data Consultant
# 524                              Data Consultant - SAS
# 525              Healthcare Data Consultant - SAS, SQL
# 526                     Data Consultant - SAS, SQL, BI
# 527                      Health System Data Consultant
# 528                          Data Analytics Consultant
# 529                              Cloud Data Consultant
# 530                   Specialty Data Consultant (USBU)
# 531                       Precision Ag Data Consultant
# 532                          Product Data Consultant I
# 533         Accenture DayNine- Workday Data Consultant
# 534         Research and Instructional Data Consultant
#
#                                          Company            City  \
# 0                                    Urner Barry      Toms River
# 1                     K2 Insurance Services, LLC       San Diego
# 2                    Central Intelligence Agency      Washington
# 3                                        Verizon         Ashburn
# 4                               Valassis Digital     Morrisville
# 5                      Kanini Software Solutions       Nashville
# 6                    Central Intelligence Agency      Washington
# 7                                       Tarifica        New York
# 8                                          Ganit   United States
# 9                                     Proofpoint       Sunnyvale
# 10              Computer Enterprises, Inc. (CEI)    Philadelphia
# 11                                        Textio         Seattle
# 12                                       TWO NIL     Playa Vista
# 13                      Lennon Wright Associates         Houston
# 14                                   R2 Commerce          Boston
# 15                              SubjectWell, Inc          Austin
# 16                                       Citrine    Redwood City
# 17                              SubjectWell, Inc          Austin
# 18                                  Indeed Prime         Atlanta
# 19                   Central Intelligence Agency      Washington
# 20                   Central Intelligence Agency      Washington
# 21                                   Urner Barry      Toms River
# 22                    K2 Insurance Services, LLC       San Diego
# 23                              SubjectWell, Inc          Austin
# 24                              Valassis Digital     Morrisville
# 25                                          Uber   San Francisco
# 26                                          Uber   San Francisco
# 27                                       TWO NIL     Playa Vista
# 28                                     Okaya Inc       Bradenton
# 29                                          Uber        New York
# ..                                           ...             ...
# 505                               NeoSystems LLC   Tysons Corner
# 506                             Artis Consulting      Richardson
# 507                            Walmart eCommerce  Salt Lake City
# 508                               Walmart Stores  Salt Lake City
# 509                            Walmart eCommerce       Sunnyvale
# 510                                       Kaizen            West
# 511                                  Learnbeyond      Piscataway
# 512                               Walmart Stores       Sunnyvale
# 513                 HealthSavings Administrators        Richmond
# 514                                  CyberCoders          Austin
# 515          Ingham Intermediate School District           Mason
# 516                           UnitedHealth Group       Santa Ana
# 517                                      Experfy          Boston
# 518                                    Accenture        New York
# 519                                      Experfy          Boston
# 520                           UnitedHealth Group       Santa Ana
# 521                                      Pythian   United States
# 522                 HealthSavings Administrators        Richmond
# 523                        Reynolds and Reynolds         Houston
# 524                            Kaiser Permanente         Oakland
# 525                            Kaiser Permanente         Oakland
# 526                            Kaiser Permanente         Oakland
# 527            Peninsula Regional Medical Center       Salisbury
# 528                                 Florida Blue    Jacksonville
# 529                                Burwood Group         Raleigh
# 530                       Takeda Pharmaceuticals       Lexington
# 531                                 FullField AG          Seward
# 532                                     Allstate        Chandler
# 533                                    Accenture        New York
# 534          Ingham Intermediate School District           Mason
#
#              State                                    Job Description  \
# 0               NJ  job summary: the data scientist is part of the...
# 1               CA  k2 insurance services, llc is seeking a full-t...
# 2               DC  as a data scientist for the cia, you will orga...
# 3               VA  what you’ll be doing... be a part of the team ...
# 4               NC  staff data scientist – machine learning & real...
# 5               TN  data scientist:databricks with spark, scala, s...
# 6               DC  as a data scientist undergraduate intern for t...
# 7               NY  about the positiontarifica develops and mainta...
# 8    United States  location: usa – multiple locations 2+ years of...
# 9               CA  it's fun to work in a company where people tru...
# 10              PA  data scientist (predictive analytics) location...
# 11              WA  we believe that the future of business writing...
# 12              CA  two nil is a growth consultancy that uses a ho...
# 13              TX  our company has partnered up with a world-clas...
# 14              MA  senior nlp data scientistwe are currently work...
# 15              TX  about subjectwellsubjectwell helps patients wi...
# 16              CA  work closely with our customers to solve chall...
# 17              TX  about subjectwellsubjectwell helps patients wi...
# 18              GA  indeed prime is working with one of atlanta's ...
# 19              DC  as a data scientist for the cia, you will orga...
# 20              DC  as a data scientist undergraduate intern for t...
# 21              NJ  job summary: the data scientist is part of the...
# 22              CA  k2 insurance services, llc is seeking a full-t...
# 23              TX  about subjectwellsubjectwell helps patients wi...
# 24              NC  staff data scientist – machine learning & real...
# 25              CA  at uber, we ignite opportunity by setting the ...
# 26              CA  at uber, we ignite opportunity by setting the ...
# 27              CA  two nil is a growth consultancy that uses a ho...
# 28              FL  job title:  data scientistlocation:  bradenton...
# 29              NY  at uber, we ignite opportunity by setting the ...
# ..             ...                                                ...
# 505             VA  the role of associate consultant, technology c...
# 506             TX  to apply, send a copy of your resume to artis_...
# 507             UT  position description  demonstrates up-to-date ...
# 508             UT  position description  demonstrates up-to-date ...
# 509             CA  position description  provide technical leader...
# 510             TX  location: remote, ideally west coast. (25% tra...
# 511             NJ  informatica big data consultant job brief we a...
# 512             CA  position description  provide technical leader...
# 513             VA  purposeat healthsavings, we’re creating a heal...
# 514             TX  senior data consultant - data science/saas (50...
# 515             MI  under the direction of the administrator, deve...
# 516             CA  expanding access to affordable, high quality h...
# 517             MA  experfy is a harvard-incubated platform (https...
# 518             NY  wanted: workday innovators ready to innovate a...
# 519             MA  experfy is a harvard-incubated platform (https...
# 520             CA  expanding access to affordable, high quality h...
# 521  United States  big data architect consultantunited states | c...
# 522             VA  purposeat healthsavings, we’re creating a heal...
# 523             TX  are you interested in furthering your career i...
# 524             CA  under general supervision, this position exist...
# 525             CA  under general supervision, this position exist...
# 526             CA  under general supervision, this position exist...
# 527             MD  responsible for modeling complex organizationa...
# 528             FL  “commercial analytics” area is comprised of th...
# 529             NC  cloud data consultant who we are burwood group...
# 530             MA  are you looking for a patient-focused, innovat...
# 531             NE  job description: responsible for building and ...
# 532             AZ  where good people build rewarding careers. thi...
# 533             NY  wanted: workday innovators ready to innovate a...
# 534             MI  under the direction of the administrator, deve...
#
#                                              Skill Set     Salary  \
# 0                               python,data mining,sql       0.00
# 1                    python,java,excel,data mining,sas       0.00
# 2                                                        97015.00
# 3    python,excel,data mining,sql,aws,machine learn...       0.00
# 4                                     machine learning       0.00
# 5    python,scala,spark,sql,machine learning,deep l...       0.00
# 6                                                        50487.84
# 7                   python,excel,visualization,tableau       0.00
# 8                                                            0.00
# 9                              python,machine learning       0.00
# 10                             python,big data,sas,sql  145000.00
# 11                      machine learning,visualization       0.00
# 12     python,excel,sql,machine learning,visualization       0.00
# 13   python,excel,data mining,hadoop,sql,machine le...  140000.00
# 14                                                      185000.00
# 15          python,excel,sas,sql,visualization,tableau  140000.00
# 16   python,java,scala,machine learning,artificial ...       0.00
# 17          python,excel,sas,sql,visualization,tableau  140000.00
# 18   java,c++,ruby,big data,sas,mahout,machine lear...  105000.00
# 19                                                       97015.00
# 20                                                       50487.84
# 21                              python,data mining,sql       0.00
# 22                   python,java,excel,data mining,sas       0.00
# 23          python,excel,sas,sql,visualization,tableau  140000.00
# 24                                    machine learning       0.00
# 25                         python,sql,machine learning       0.00
# 26                        python,java,machine learning       0.00
# 27     python,excel,sql,machine learning,visualization       0.00
# 28   python,java,excel,data mining,sas,visualizatio...       0.00
# 29                         python,sql,machine learning       0.00
# ..                                                 ...        ...
# 505                                    java,sql,c#,etl       0.00
# 506  java,data mining,big data,hadoop,visualization...       0.00
# 507                    java,javascript,splunk,hive,sql       0.00
# 508                    java,javascript,splunk,hive,sql       0.00
# 509              java,javascript,excel,splunk,hive,sql       0.00
# 510                                java,big data,spark       0.00
# 511  python,scala,big data,hadoop,spark,hive,sql,no...       0.00
# 512              java,javascript,excel,splunk,hive,sql       0.00
# 513  python,excel,big data,sas,hadoop,sql,nosql,hba...       0.00
# 514                                      visualization  115000.00
# 515                                                sas   86670.50
# 516                                    excel,sql,mysql       0.00
# 517  scala,big data,hadoop,mapreduce,spark,pig,hive...  261000.00
# 518                      scala,excel,sas,sql,mysql,etl       0.00
# 519  scala,big data,hadoop,mapreduce,spark,pig,hive...  261000.00
# 520                                    excel,sql,mysql       0.00
# 521  python,java,scala,hadoop,mapreduce,spark,hive,...  160000.00
# 522  python,excel,big data,sas,hadoop,sql,nosql,hba...       0.00
# 523                                              excel       0.00
# 524                                  excel,sas,sql,aws       0.00
# 525                                  excel,sas,sql,aws       0.00
# 526                                  excel,sas,sql,aws       0.00
# 527                          data mining,visualization       0.00
# 528                                      excel,sas,sql       0.00
# 529                       python,sql,azure,tableau,etl       0.00
# 530                                              excel       0.00
# 531                                                          0.00
# 532           sas,sql,mysql,visualization,tableau,unix       0.00
# 533                      scala,excel,sas,sql,mysql,etl       0.00
# 534                                                sas   86670.50
#
#          Education  Experience
# 0               ba           1
# 1               bs           5
# 2               ba           0
# 3               ba           0
# 4               ba           5
# 5    Not Mentioned           5
# 6               ba           0
# 7               ba           0
# 8    Not Mentioned           2
# 9               ba           0
# 10              ba           0
# 11              ba           0
# 12              ba           0
# 13              bs           0
# 14              ba           1
# 15              ba           0
# 16              ba           0
# 17              ba           0
# 18              bs           4
# 19              ba           0
# 20              ba           0
# 21              ba           1
# 22              bs           5
# 23              ba           0
# 24              ba           5
# 25              ba           0
# 26              ba           0
# 27              ba           0
# 28              ba           5
# 29              ba           0
# ..             ...         ...
# 505             bs           2
# 506             ba           2
# 507             ba           4
# 508             ba           4
# 509             bs           2
# 510             ms           2
# 511             ba           0
# 512             bs           2
# 513             ba           5
# 514             ba           5
# 515             bs           3
# 516             ms           3
# 517             ba           4
# 518             ba           2
# 519             ba           4
# 520             ms           3
# 521             bs           5
# 522             ba           5
# 523             ba           0
# 524             ba           0
# 525             ba           0
# 526             ba           0
# 527             ba           0
# 528             ba           0
# 529             ba           0
# 530             bs           0
# 531             ba           3
# 532             bs           3
# 533             ba           2
# 534             bs           3
#
# [535 rows x 9 columns]

# %%
#remove duplicate
data = data[~data[['Job Title','Company','City','Job Description']].apply(frozenset, axis=1).duplicated()]

#remove white spaces
trimmed_df = data.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

#save excel file to local drive
export_excel = trimmed_df.to_excel(r'C:\Users\Rich\Desktop\612_dataframe.xlsx', index = None, header = True)
